# %% [markdown]
# <a href="https://colab.research.google.com/github/s2ul2/This-is-coding-test-with-Python/blob/main/%EC%A0%95%EB%A0%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chap6

# %% [markdown]
# ## 계수 정렬

# %%
# 모든 원소의 값이 0보다 크거나 같다고 가정
array = [7, 5, 9, 0, 3, 1, 6, 2, 9, 1, 4, 8, 0, 5, 2]
# 모든 범위를 포함하는 리스트 선언 (모든 값은 0으로 초기화)
count = [0] * (max(array) + 1)

for i in range(len(array)):
    count[array[i]] += 1 # 각 데이터에 해당하는 인덱스의 값 증가

for i in range(len(count)): # 리스트에 기록된 정렬 정보 확인
    for j in range(count[i]):
        print(i, end=' ') # 띄어쓰기를 구분으로 등장한 횟수만큼 인덱스 출력

# %% [markdown]
# ## 정렬 비교

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 파이썬에서 제공하는 기본 정렬 라이브러리를 사용하자.
# * -->  sorted(정렬하고자하는 리스트(or 딕셔너리),  key = 함수(or lambda))  --> output : 리스트
# * --> 리스트.sort() : 바로 정렬해줌.
# * 만일 데이터의 범위가 한정되어있고 중복값이 많은 경우에는 계수 정렬 사용하자.

# %% [markdown]
# ## 위에서 아래로

# %%
n = int(input())
lst = []
for i in range(n):
    lst.append(int(input()))
sort_lst = sorted(lst, reverse = True)
for n in sort_lst:
    print(n, end = ' ')
# Out:
# 3
# 15
# 27
# 12
# 27 15 12

# %% [markdown]
# ## 성적이 낮은 순서로 학생 출력하기 : 3분

# %%
n = int(input())
std_lst = []
for i in range(n):
    name, score = input().split()
    std_lst.append([name, score])
sort_lst = sorted(std_lst, key = lambda x: x[1])
for std in sort_lst:
    print(std[0], end = ' ')
# Out:
# 2
# 홍길동 95
# 이순신 77
# 이순신 홍길동

# %% [markdown]
# ## 두 배열의 원소 교체 : 12분

# %% [markdown]
# * a의 작은 원소와 b의 큰 원소 교체

# %%
# n : 원소개수, k : 최대 바꿔치기 횟수
n, k = map(int, input().split())
a_lst = map(int, input().split())
a_sort = sorted(a_lst) # 오름차순
b_lst = map(int, input().split())
b_sort = sorted(b_lst, reverse = True) # 내림차순

cnt = 0
for i in range(n):
    if cnt == k:
        break
    if a_sort[i] < b_sort[i]: # a_sort에 담긴 값이 더 작다면 -> swap
        a_sort[i], b_sort[i] = b_sort[i], a_sort[i]
        cnt += 1
    else: # a_sort에 담긴 값이 같거나 크다면 그 이후에 있는 값도 마찬가지이므로 for문 돌 필요 없음 -> break
        break
print(sum(a_sort))
# Out:
# 5 3
# 1 2 5 4 3
# 5 5 6 6 5
# 26

# %% [markdown]
# ### 책 풀이

# %%
n, k = map(int, input().split()) # N과 K를 입력 받기
a = list(map(int, input().split())) # 배열 A의 모든 원소를 입력받기
b = list(map(int, input().split())) # 배열 B의 모든 원소를 입력받기

a.sort() # 배열 A는 오름차순 정렬 수행
b.sort(reverse=True) # 배열 B는 내림차순 정렬 수행

# 첫 번째 인덱스부터 확인하며, 두 배열의 원소를 최대 K번 비교
for i in range(k):
    # A의 원소가 B의 원소보다 작은 경우
    if a[i] < b[i]:
        # 두 원소를 교체
        a[i], b[i] = b[i], a[i]
    else: # A의 원소가 B의 원소보다 크거나 같을 때, 반복문을 탈출
        break

print(sum(a)) # 배열 A의 모든 원소의 합을 출력

# %% [markdown]
# 나랑 비슷하긴 한데, for문 돌릴 때 k 범위로 돌려도 상관없다!!

# %% [markdown]
# # Chap 14

# %% [markdown]
# ## 국영수 : 11분 57초 (다중 조건 검색해봄)

# %%
n = int(input())
std_lst = []
for i in range(n):
    name, kor, eng, math = input().split()
    std_lst.append([name, int(kor), int(eng), int(math)])
# 국어 감소 -> 영어 증가 -> 수학 감소 -> 이름 증가
sort_lst = sorted(std_lst, key = lambda x: (-x[1], x[2], -x[3], x[0]) ) # 다중 조건
for std in sort_lst:
    print(std[0])
# Out:
# 12
# Junkyu 50 60 100
# Sangkeun 80 60 50
# Sunyoung 80 70 100
# Soong 50 60 90
# Heabin 50 60 100
# Kangsoo 60 80 100
# Donghyuk 80 60 100
# Sei 70 70 70
# Wonseob 70 70 90
# Sanghyun 70 70 80
# nsj 80 80 80
# Taewhan 50 60 90
# Donghyuk
# Sangkeun
# Sunyoung
# nsj
# Wonseob
# Sanghyun
# Sei
# Kangsoo
# Heabin
# Junkyu
# Soong
# Taewhan

# %% [markdown]
# ### 책 풀이

# %%
n = int(input())
students = [] # 학생 정보를 담을 리스트

# 모든 학생 정보를 입력 받기
for _ in range(n):
    students.append(input().split())

'''
[ 정렬 기준 ]
1) 두 번째 원소를 기준으로 내림차순 정렬
2) 두 번째 원소가 같은 경우, 세 번째 원소를 기준으로 오름차순 정렬
3) 세 번째 원소가 같은 경우, 네 번째 원소를 기준으로 내림차순 정렬
4) 네 번째 원소가 같은 경우, 첫 번째 원소를 기준으로 오름차순 정렬
'''
students.sort(key=lambda x: (-int(x[1]), int(x[2]), -int(x[3]), x[0]))

# 정렬된 학생 정보에서 이름만 출력
for student in students:
    print(student[0])

# %% [markdown]
# * 튜플을 원소로하는 리스트가 있을 때, 그 리스트를 정렬하면 기본적으로 각 튜플을 구성하는 원소의 순서에 맞게 정렬됨.
# * 리스트의 원소를 정렬할 때 자신이 원하는 조건에 맞게 튜플을 정렬시킬 수 있다.

# %% [markdown]
# ## 안테나 : 틀림

# %%
n = int(input()) # 집의 수
sum_loc = 0
print(sum(list(map(int, input().split()))) // n)
# Out:
# 4
# 5 1 7 9
# 5

# %% [markdown]
# 안테나는 집이 위치한 곳에만 설치할 수 있다는 조건을 못봤음..

# %%
# 두번째 풀이 : 틀림 
# 안테나는 평균값과 인접한 집에 설치해야함.  --> 틀림 !!!
n = int(input())
house_loc = list(map(int, input().split()))
house_loc.sort()
avg_loc = sum(house_loc) / n
diff_lst = list(map(lambda x: abs(x - avg_loc), house_loc))
min_val = min(diff_lst)
print(house_loc[diff_lst.index(min_val)])
# Out:
# 5
# 1 2 3 70 1000
# 70

# %% [markdown]
# ### 책 풀이

# %%
# 안테나는 중간값에 설치해야함.
n = int(input())
a = list(map(int, input().split()))
a.sort()

# 중간값(median)을 출력
print(a[(n - 1) // 2])
# Out:
# 5
# 1 2 3 70 1000
# 3

# %% [markdown]
# ## 실패율 : 해결 o (25분)

# %%
def solution(N, stages):
    participant = len(stages)
    fail_lst = []
    for n in range(1, N+1):
        fail_num = stages.count(n)
        try:
            fail_rate = fail_num / participant
        except:
            fail_rate = 0
        fail_lst.append(fail_rate)
        participant -= fail_num
    stage_lst = []
    for i in range(1, N+1):
        stage_lst.append(i)
    return sorted(stage_lst, key = lambda x : fail_lst[x-1], reverse = True)

# %% [markdown]
# 두번째 푸는건데도 오래걸리네,,

# %% [markdown]
# ### 책 풀이

# %%
def solution(N, stages):
    answer = []
    length = len(stages)

    # 스테이지 번호를 1부터 N까지 증가시키며
    for i in range(1, N + 1):
        # 해당 스테이지에 머물러 있는 사람의 수 계산
        count = stages.count(i)
        
        # 실패율 계산
        if length == 0:
            fail = 0
        else:
            fail = count / length
        
        # 리스트에 (스테이지 번호, 실패율) 원소 삽입
        answer.append((i, fail))
        length -= count

    # 실패율을 기준으로 각 스테이지를 내림차순 정렬
    answer = sorted(answer, key=lambda t: t[1], reverse=True)
    
    # 정렬된 스테이지 번호 반환
    answer = [i[0] for i in answer]
    return answer

# %% [markdown]
# 나는 stage_lst를 따로 만들었는데 이는 공간만 차지함.
#
# 책에 나온 것처럼 스테이지 번호와 실패율을 튜플로 묶어서 리스트에 저장하는 것이 더 좋을듯!

# %% [markdown]
# ### 또 다른 방법 (다른사람 풀이 : 딕셔너리 사용)

# %%
def solution(N, stages):
    result = {}
    denominator = len(stages) # 도전자수
    for stage in range(1, N+1):
        if denominator != 0:
            count = stages.count(stage)
            result[stage] = count / denominator
            denominator -= count
        else:
            result[stage] = 0
    return sorted(result, key=lambda x : result[x], reverse=True)

# %% [markdown]
# result는 dictionary이므로 sorted에 result를 그냥 넘기면 result의 keys가 들어갑니다. keys는 생략이 가능합니다. 거기에 lambda는 기준을 result[x]: 즉 value로 정렬한다는 뜻입니다. 그래서 key가 출력되게 됩니다.

# %% [markdown]
# ## 카드 정렬하기 : 8분 (맞는건지 모르겠음, 결과는 잘 나오긴 하는데,,)

# %%
n = int(input())
card_lst = []
for i in range(n):
    card_lst.append(int(input()))
card_lst.sort()
total = 0
for i in range(2, len(card_lst)+1):
    total += sum(card_lst[:i])

print(total)

# 10 20 40 = (10+20) + (10 + 20 + 40) = 70
# 10 20 40 50 = (10+20) + (10+20+40) + (10+20+40+50)
# Out:
# 4
# 10
# 20
# 40
# 50
# 220

# %% [markdown]
# ### 책 풀이 : 우선순위 큐 사용

# %% [markdown]
# * 매 상황에서 무조건 가장 작은 크기의 두 카드 묶음을 합친다.
# * 우선순위 큐 : 정렬 안된 원소를 무작위로 input으로 넣어도 output은 항상 작은 값 순서로 나온다.

# %%
import heapq

n = int(input())

# 힙(Heap)에 초기 카드 묶음을 모두 삽입
heap = []
for i in range(n):
    data = int(input())
    heapq.heappush(heap, data)

result = 0

# 힙(Heap)에 원소가 1개 남을 때까지 (즉 1개 남으면 종료)
while len(heap) != 1:
    # 가장 작은 2개의 카드 묶음 꺼내기
    one = heapq.heappop(heap)
    two = heapq.heappop(heap)
    # 카드 묶음을 합쳐서 다시 삽입
    sum_value = one + two
    result += sum_value
    heapq.heappush(heap, sum_value) # 합친 값 큐에 삽입

print(result)

# %% [markdown]
# * 우선순위 큐 : import heapq
# * 삽입 : heapq.heappush(리스트, 원소)
# * 삭제 : heapq.heappop(리스트)
